# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from scipy import stats

# %%
from modules.truth import truth # just to look at the list of scenarios to plot
from modules.plotting import trim_data,trim_data_2n0,contours,scatter # functions to make contour plots
from modules.sn_models import snowglobes_curves,other_sn_models # functions to plot supernova models

# %%
inputfile = 'input.txt'
truth = truth(inputfile)

# %%
# For reference, here are the different scenarios I'm plotting
for config in truth:
    print(config,truth[config])
# Out:
# halo1_5kpc [[72, 48], [40, 12], [16, 0]]
# halo1_10kpc [[18, 12], [10, 3], [4, 0]]
# halo2_10kpc [[227, 151], [127, 38], [51, 0]]

# %%
# where the unfolded data lives
unfolded_location = './unfolded_data/'

# %% [markdown]
# ## Plot style settings

# %%
figsize = (8,6)
plt.rc('font', family='sans-serif')
plt.rc('axes', labelsize='xx-large')
plt.rc('xtick', labelsize='large')
plt.rc('ytick', labelsize='large')
plt.rc('axes',titlesize='xx-large')
truth_size = 200
exp_size = 30
dist_size = 20
#print(plt.rcParams.keys())

# %% [markdown]
# # PLOTS

# %% [markdown]
# ## Matrix inversion

# %% [markdown]
# ##### HALO1, 5kpc

# %%
# Data for HALO 1, 5kpc, 72v48 40vs12 16v0
h1_5kpc_72v48_1n, h1_5kpc_72v48_2n = np.load(unfolded_location+'halo1_5kpc_72v48_unfolded_matrix.npy')
h1_5kpc_40v12_1n, h1_5kpc_40v12_2n = np.load(unfolded_location+'halo1_5kpc_40v12_unfolded_matrix.npy')
h1_5kpc_16v0_1n,  h1_5kpc_16v0_2n  = np.load(unfolded_location+'halo1_5kpc_16v0_unfolded_matrix.npy')

# %%
# HALO 1, 5kpc, 72vs48
xM1_1,yM1_1,cutM1_1 = trim_data(h1_5kpc_72v48_1n,h1_5kpc_72v48_2n)
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#contours(xM1_1,yM1_1,cutM1_1,ax)
#scatter(xM1_1,yM1_1,ax)

# %%
# HALO 1, 5kpc, 40vs12
xM1_2,yM1_2,cutM1_2 = trim_data(h1_5kpc_40v12_1n,h1_5kpc_40v12_2n)
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#contours(xM1_2,yM1_2,cutM1_2,ax)
#scatter(xM1_2,yM1_2,ax)

# %%
# HALO 1, 5kpc, 16vs0
xM1_3,yM1_3,cutM1_3 = trim_data_2n0(h1_5kpc_16v0_1n)
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#contours(xM1_3,yM1_3,cutM1_3,ax,x_bw=np.std(xM1_3)/4)
#scatter(xM1_3,yM1_3,ax)

# manual fix of clipped contour
#x_manfix = [2.5,2.5]
#y_manfix = [-0.7,0.7]
#ax.plot(x_manfix,y_manfix,color='black')

# %%
# Figure for HALO 1, 5kpc, 72v48 40vs12 16v0
figM1,axM1 = plt.subplots(1,1,figsize=figsize)

contours(xM1_1,yM1_1,cutM1_1,axM1)
contours(xM1_2,yM1_2,cutM1_2,axM1)
contours(xM1_3,yM1_3,cutM1_3,axM1,x_bw=np.std(xM1_3)/4)

# manual fix of clipped contour
x_manfix = [2.5,2.5]
y_manfix = [-0.7,0.7]
axM1.plot(x_manfix,y_manfix,color='black')

other_sn_models(axM1,1,5,False)
snowglobes_curves(axM1,1,5,False)

# Truth values
Truth = [[72,40,16],[48,12,0]]
axM1.scatter(Truth[0],Truth[1],color='b',marker='*',s=truth_size)

# Title
axM1.set_title('Matrix Inversion')
axM1.text(0.7,0.8,'HALO',fontsize=exp_size,transform=axM1.transAxes)
axM1.text(0.74,0.74,'5kpc',fontsize=dist_size,transform=axM1.transAxes)


axM1.set_xlim(-15,150)
axM1.set_ylim(-15,105)

pylab.savefig('./figures/matrix_unfolding_halo1_5kpc.png')

plt.show()

# %% [markdown]
# ##### HALO1, 10kpc

# %%
# Data for HALO 1, 10kpc, 18v12 10vs3 4v0
h1_10kpc_18v12_1n, h1_10kpc_18v12_2n = np.load(unfolded_location+'halo1_10kpc_18v12_unfolded_matrix.npy')
h1_10kpc_10v3_1n,  h1_10kpc_10v3_2n  = np.load(unfolded_location+'halo1_10kpc_10v3_unfolded_matrix.npy')
h1_10kpc_4v0_1n,   h1_10kpc_4v0_2n   = np.load(unfolded_location+'halo1_10kpc_4v0_unfolded_matrix.npy')

# %%
# HALO 1, 10kpc, 18v12
xM2_1,yM2_1,cutM2_1 = trim_data(h1_10kpc_18v12_1n,h1_10kpc_18v12_2n)
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#contours(xM2_1,yM2_1,cutM2_1,ax,x_bw=8,y_bw=8)
#scatter(xM2_1,yM2_1,ax)

# %%
# HALO 1, 10kpc, 10vs3
xM2_2,yM2_2,cutM2_2 = trim_data(h1_10kpc_10v3_1n,h1_10kpc_10v3_2n)
xM2_2 -= 2
yM2_2 += 5
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#contours(xM2_2,yM2_2,cutM2_2,ax,x_bw=3,y_bw=5)
#scatter(xM2_2+2,yM2_2-5,ax)

# %%
# HALO 1, 10kpc, 4vs0
xM2_3,yM2_3,cutM2_3 = trim_data_2n0(h1_10kpc_4v0_1n)
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#ax.set_xlim(-5,15)
#contours(xM2_3,yM2_3,cutM1_3,ax,x_bw=np.std(xM2_3)/3)
#scatter(xM2_3,yM2_3,ax)
# manual fix of clipped contour
#x_manfix1 = [-3.2,-3.2]
#y_manfix1 = [-1.1,1.1]
#ax.plot(x_manfix1,y_manfix1,color='black')
#x_manfix2 = [13.9,13.9]
#y_manfix2 = [-0.6,0.6]
#ax.plot(x_manfix2,y_manfix2,color='black')

# %%
# Figure for HALO 1, 10kpc, 18v12 10vs3 4v0
figM2,axM2 = plt.subplots(1,1,figsize=figsize)

contours(xM2_1,yM2_1,cutM2_1,axM2,x_bw=8,y_bw=8)
contours(xM2_2,yM2_2,cutM2_2,axM2,x_bw=3,y_bw=5)
contours(xM2_3,yM2_3,cutM2_3,axM2,x_bw=np.std(xM2_3)/3)

# manual fix of clipped contour
x_manfix1 = [-3.2,-3.2]
y_manfix1 = [-1.1,1.1]
axM2.plot(x_manfix1,y_manfix1,color='black')
x_manfix2 = [13.9,13.9]
y_manfix2 = [-0.6,0.6]
axM2.plot(x_manfix2,y_manfix2,color='black')

other_sn_models(axM2,1,10,False)
snowglobes_curves(axM2,1,10,False)

# Truth values
Truth = [[18,10,4],[12,3,0]]
axM2.scatter(Truth[0],Truth[1],color='b',marker='*',s=truth_size)

# Title
axM2.set_title('Matrix Inversion')
axM2.text(0.7,0.8,'HALO',fontsize=exp_size,transform=axM2.transAxes)
axM2.text(0.73,0.74,'10kpc',fontsize=dist_size,transform=axM2.transAxes)


axM2.set_xlim(-15,60)
axM2.set_ylim(-10,35)

pylab.savefig('./figures/matrix_unfolding_halo1_10kpc.png')

plt.show()

# %% [markdown]
# ##### HALO2, 10kpc

# %%
# Data for HALO 2, 10kpc, 227v151 127vs38 51v0
h2_10kpc_227v151_1n, h2_10kpc_227v151_2n = np.load(unfolded_location+'halo2_10kpc_227v151_unfolded_matrix.npy')
h2_10kpc_127v38_1n,  h2_10kpc_127v38_2n  = np.load(unfolded_location+'halo2_10kpc_127v38_unfolded_matrix.npy')
h2_10kpc_51v0_1n,    h2_10kpc_51v0_2n    = np.load(unfolded_location+'halo2_10kpc_51v0_unfolded_matrix.npy')

# %%
# NOT YET DONE

# HALO 2, 10kpc, 227vs151
xM3_1,yM3_1,cutM3_1 = trim_data(h2_10kpc_227v151_1n,h2_10kpc_227v151_2n)
fig,ax = plt.subplots(1,1,figsize=(8,6))
contours(xM3_1,yM3_1,cutM3_1,ax)
scatter(xM3_1,yM3_1,ax)

# %%
# NOT DONE YET

# HALO 2, 10kpc, 127vs38
xM3_2,yM3_2,cutM3_2 = trim_data(h2_10kpc_127v38_1n,h2_10kpc_127v38_2n)
fig,ax = plt.subplots(1,1,figsize=(8,6))
contours(xM3_2,yM3_2,cutM3_2,ax)
scatter(xM3_2,yM3_2,ax)

# %%
# NOT DONE YET

# HALO 2, 10kpc, 51vs0
xM3_3,yM3_3,cutM3_3 = trim_data(h2_10kpc_51v0_1n,h2_10kpc_51v0_2n)
fig,ax = plt.subplots(1,1,figsize=(8,6))
contours(xM3_3,yM3_3,cutM3_3,ax)
scatter(xM3_3,yM3_3,ax)

# %%
# Figure for HALO 2, 10kpc, 227v151 127vs38 51v0
figM3,axM3 = plt.subplots(1,1,figsize=figsize)

contours(xM3_1,yM3_1,cutM3_1,axM3)
contours(xM3_2,yM3_2,cutM3_2,axM3)
contours(xM3_3,yM3_3,cutM3_3,axM3)

other_sn_models(axM3,2,10,False)
snowglobes_curves(axM3,2,10,False)

# Truth values
Truth = [[227,127,51],[151,38,0]]
axM3.scatter(Truth[0],Truth[1],color='b',marker='*',s=truth_size)

# Title
axM3.set_title('Matrix Inversion')
axM3.text(0.62,0.86,'HALO-1kT',fontsize=exp_size,transform=axM3.transAxes)
axM3.text(0.72,0.80,'10kpc',fontsize=dist_size,transform=axM3.transAxes)


axM3.set_xlim(0,375)
axM3.set_ylim(-15,265)

pylab.savefig('./figures/matrix_unfolding_halo2_10kpc.png')

plt.show()

# %% [markdown]
# ## Bayesian

# %% [markdown]
# #### Positive Plane Prior

# %% [markdown]
# ##### HALO1, 5kpc

# %%
# Data for HALO 1, 5kpc, 72v48 40vs12 16v0
h1_5kpc_72v48_1n, h1_5kpc_72v48_2n = np.load(unfolded_location+'halo1_5kpc_72v48_unfolded_bayesian_PP.npy')
h1_5kpc_40v12_1n, h1_5kpc_40v12_2n = np.load(unfolded_location+'halo1_5kpc_40v12_unfolded_bayesian_PP.npy')
h1_5kpc_16v0_1n,  h1_5kpc_16v0_2n  = np.load(unfolded_location+'halo1_5kpc_16v0_unfolded_bayesian_PP.npy')

# %%
# HALO 1, 5kpc, 72vs48
xBpp1_1,yBpp1_1,cutBpp1_1 = trim_data(h1_5kpc_72v48_1n,h1_5kpc_72v48_2n)
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#contours(xBpp1_1,yBpp1_1,cutBpp1_1,ax)
#scatter(xBpp1_1,yBpp1_1,ax)

# %%
# HALO 1, 5kpc, 40vs12
xBpp1_2,yBpp1_2,cutBpp1_2 = trim_data(h1_5kpc_40v12_1n,h1_5kpc_40v12_2n)
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#contours(xBpp1_2,yBpp1_2,cutBpp1_2*0.8,ax,x_bw=np.std(xBpp1_2)/2)
#scatter(h1_5kpc_40v12_1n,h1_5kpc_40v12_2n,ax)
#scatter(xBpp1_2,yBpp1_2,ax)

# %%
# HALO 1, 5kpc, 16vs0
xBpp1_3,yBpp1_3,cutBpp1_3 = trim_data_2n0(h1_5kpc_16v0_1n)
#fig,ax = plt.subplots(1,1,figsize=(8,6))
#ax.set_xlim(-5,45)
#contours(xBpp1_3,yBpp1_3,cutBpp1_3,ax)#,x_bw=np.std(xBpp1_3)/4)
#scatter(xBpp1_3,yBpp1_3,ax)
# manual fix of clipped contour
#x_manfix1 = [-3.8,-3.8]
#y_manfix1 = [-1.1,1.1]
#ax.plot(x_manfix1,y_manfix1,color='black')
#x_manfix2 = [41.8,41.8]
#y_manfix2 = [-0.7,0.7]
#ax.plot(x_manfix2,y_manfix2,color='black')

# %%
# Figure for HALO 1, 5kpc, 72v48 40vs12 16v0
figBpp1,axBpp1 = plt.subplots(1,1,figsize=figsize)

contours(xBpp1_1,yBpp1_1,cutBpp1_1,axBpp1)
contours(xBpp1_2,yBpp1_2,cutBpp1_2*0.8,axBpp1,x_bw=np.std(xBpp1_2)/2)
contours(xBpp1_3,yBpp1_3,cutBpp1_3,axBpp1)

# manual fix of clipped contour
x_manfix1 = [-3.8,-3.8]
y_manfix1 = [-1.1,1.1]
axBpp1.plot(x_manfix1,y_manfix1,color='black')
x_manfix2 = [41.8,41.8]
y_manfix2 = [-0.7,0.7]
axBpp1.plot(x_manfix2,y_manfix2,color='black')

other_sn_models(axBpp1,1,5,False)
snowglobes_curves(axBpp1,1,5,False)

# Truth values
Truth = [[72,40,16],[48,12,0]]
axBpp1.scatter(Truth[0],Truth[1],color='b',marker='*',s=truth_size)

# Title
axBpp1.set_title('Bayesian - Positive Plane Prior')
axBpp1.text(0.7,0.8,'HALO',fontsize=exp_size,transform=axBpp1.transAxes)
axBpp1.text(0.74,0.74,'5kpc',fontsize=dist_size,transform=axBpp1.transAxes)


axBpp1.set_xlim(-10,165)
axBpp1.set_ylim(-5,110)

pylab.savefig('./figures/bayesian_positiveplane_unfolding_halo1_5kpc.png')

plt.show()

# %% [markdown]
# ##### HALO1, 10kpc

# %%
# Data for HALO 1, 10kpc, 18v12 10vs3 4v0
h1_10kpc_18v12_1n, h1_10kpc_18v12_2n = np.load(unfolded_location+'halo1_10kpc_18v12_unfolded_bayesian_PP.npy')
h1_10kpc_10v3_1n,  h1_10kpc_10v3_2n  = np.load(unfolded_location+'halo1_10kpc_10v3_unfolded_bayesian_PP.npy')
h1_10kpc_4v0_1n,   h1_10kpc_4v0_2n   = np.load(unfolded_location+'halo1_10kpc_4v0_unfolded_bayesian_PP.npy')

# %%
# HALO 1, 10kpc, 18vs12
xBpp2_1,yBpp2_1,cutBpp2_1 = trim_data(h1_10kpc_18v12_1n,h1_10kpc_18v12_2n)
fig,ax = plt.subplots(1,1,figsize=(8,6))
xBpp2_1 += 4
yBpp2_1 += 3
contours(xBpp2_1,yBpp2_1,cutBpp2_1,ax,x_bw=np.std(xBpp2_1)/2)
scatter(xBpp2_1-4,yBpp2_1-3,ax)

# %%
# HALO 1, 10kpc, 10vs3
xBpp2_2,yBpp2_2,cutBpp2_2 = trim_data(h1_10kpc_10v3_1n,h1_10kpc_10v3_2n)
fig,ax = plt.subplots(1,1,figsize=(8,6))
#xBpp2_2 -= 3
#yBpp2_2 += 5
#contours(xBpp2_2,yBpp2_2,cutBpp2_2*0.1,ax,x_bw=np.std(xBpp2_2)/2)
#scatter(xBpp2_2,yBpp2_2,ax)

#x_new = []
#y_new = []
#for y in range(5,25):
#    for x in range(6,int(-13/9*(y-5)+0.5)+32):
#        x_new.append(x)
#        y_new.append(y)
#ax.scatter(x_new,y_new)
#plt.show()
#sns.kdeplot(x_new,y_new,cbar=True)
#contours(x_new,y_new,0.0008,ax)

# %%
# HALO 1, 10kpc, 4vs0
xBpp2_3,yBpp2_3,cutBpp2_3 = trim_data_2n0(h1_10kpc_4v0_1n)
fig,ax = plt.subplots(1,1,figsize=(8,6))
ax.set_xlim(-5,40)
contours(xBpp2_3,yBpp2_3,cutBpp2_3,ax,x_bw=np.std(xBpp1_3)/4)
scatter(xBpp2_3,yBpp2_3,ax)
# manual fix of clipped contour
x_manfix1 = [-1.1,-1.1]
y_manfix1 = [-1.2,1.2]
ax.plot(x_manfix1,y_manfix1,color='black')
x_manfix2 = [39.2,39.2]
y_manfix2 = [-0.9,0.9]
ax.plot(x_manfix2,y_manfix2,color='black')

# %%
# Figure for HALO 1, 10kpc, 18v12 10vs3 4v0
figBpp2,axBpp2 = plt.subplots(1,1,figsize=figsize)

contours(xBpp2_1,yBpp2_1,cutBpp2_1,axBpp2,x_bw=np.std(xBpp2_1)/2)
#contours(xBpp2_2,yBpp2_2,cutBpp2_2*0.03,axBpp2,x_bw=np.std(xBpp2_2)/2)
contours(x_new,y_new,0.0008,axBpp2)
contours(xBpp2_3,yBpp2_3,cutBpp2_3,axBpp2,x_bw=np.std(xBpp1_3)/4)

# manual fix of clipped contour
x_manfix1 = [-1.1,-1.1]
y_manfix1 = [-1.2,1.2]
axBpp2.plot(x_manfix1,y_manfix1,color='black')
x_manfix2 = [39.2,39.2]
y_manfix2 = [-0.9,0.9]
axBpp2.plot(x_manfix2,y_manfix2,color='black')

other_sn_models(axBpp2,1,10,False)
snowglobes_curves(axBpp2,1,10,False)

# Truth values
Truth = [[18,10,4],[12,3,0]]
axBpp2.scatter(Truth[0],Truth[1],color='b',marker='*',s=truth_size)

# Title
axBpp2.set_title('Bayesian - Positive Plane Prior')
axBpp2.text(0.7,0.8,'HALO',fontsize=exp_size,transform=axBpp2.transAxes)
axBpp2.text(0.73,0.74,'10kpc',fontsize=dist_size,transform=axBpp2.transAxes)


axBpp2.set_xlim(-10,60)
axBpp2.set_ylim(-5,45)

pylab.savefig('./figures/bayesian_positiveplane_unfolding_halo1_10kpc.png')

plt.show()
